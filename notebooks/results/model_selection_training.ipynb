# %%
# %reload_kedro
# Out:
# 2023-03-12 22:30:13,190 - kedro.extras.extensions.ipython - INFO - No path argument was provided. Using: /Users/guilhermepalazzo/Desktop/dev/git_repositories/crypto_msc_thesis
# 2023-03-12 22:30:14,659 - kedro.framework.session.store - INFO - `read()` not implemented for `BaseSessionStore`. Assuming empty store.
# 2023-03-12 22:30:14,922 - kedro.extras.extensions.ipython - INFO - ** Kedro project crypto_thesis
# 2023-03-12 22:30:14,927 - kedro.extras.extensions.ipython - INFO - Defined global variable `context`, `session`, `catalog` and `pipelines`

# %%
from sklearn.metrics import roc_auc_score, classification_report, roc_curve
import matplotlib.pyplot as plt

# %%
plt.style.use("grayscale")

# %% [markdown]
# ### XGBoost

# %%
model = catalog.load("xgboost_fitted_model")
X_test = catalog.load("xgboost_features_test")
y_test = catalog.load("xgboost_target_test")
y_pred = catalog.load("xgboost_model_predict")
# Out:
# 2023-03-12 22:30:16,149 - kedro.io.data_catalog - INFO - Loading data from `xgboost_fitted_model` (PickleDataSet)...
# 2023-03-12 22:30:16,255 - kedro.io.data_catalog - INFO - Loading data from `xgboost_features_test` (ParquetDataSet)...
# 2023-03-12 22:30:16,324 - kedro.io.data_catalog - INFO - Loading data from `xgboost_target_test` (ParquetDataSet)...
# 2023-03-12 22:30:16,335 - kedro.io.data_catalog - INFO - Loading data from `xgboost_model_predict` (ParquetDataSet)...

# %%
_roc_auc_score = roc_auc_score(y_true=y_test, y_score=y_pred)
_roc_auc_score
# Out:
# 0.6581989957716702

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.77      0.70       352
#            1       0.70      0.55      0.61       344
#
#     accuracy                           0.66       696
#    macro avg       0.67      0.66      0.65       696
# weighted avg       0.67      0.66      0.66       696

# %%
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])

plt.figure()

plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % _roc_auc_score)
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('XGBoost ROC Curve')
plt.legend(loc="lower right")

plt.savefig("/Users/guilhermepalazzo/Desktop/fig_xgboost_roc_curve.png")

# %% [markdown]
# ### LSTM

# %%
from crypto_thesis.data_domains.modeling.lstm import _build_lstm_timestamps_seq

# %%
y_test = catalog.load("lstm_target_test")
y_pred = catalog.load("lstm_model_predict")
X_test = catalog.load("lstm_features_test")

model = catalog.load("lstm_fitted_model")

seq_length = catalog.load("params:lstm_timestamp_seq_length")
# Out:
# 2023-03-12 22:30:17,080 - kedro.io.data_catalog - INFO - Loading data from `lstm_target_test` (ParquetDataSet)...
# 2023-03-12 22:30:17,110 - kedro.io.data_catalog - INFO - Loading data from `lstm_model_predict` (ParquetDataSet)...
# 2023-03-12 22:30:17,122 - kedro.io.data_catalog - INFO - Loading data from `lstm_features_test` (ParquetDataSet)...
# 2023-03-12 22:30:17,158 - kedro.io.data_catalog - INFO - Loading data from `lstm_fitted_model` (TensorFlowModelDataset)...
# 2023-03-12 22:30:17.290790: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-12 22:30:20,861 - kedro.io.data_catalog - INFO - Loading data from `params:lstm_timestamp_seq_length` (MemoryDataSet)...

# %%
_roc_auc_score = roc_auc_score(y_true=y_test, y_score=y_pred)
_roc_auc_score
# Out:
# 0.502906976744186

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      1.00      0.67       352
#            1       1.00      0.01      0.01       344
#
#     accuracy                           0.51       696
#    macro avg       0.75      0.50      0.34       696
# weighted avg       0.75      0.51      0.35       696

# %%
X_test, _ = _build_lstm_timestamps_seq(X=X_test, y=y_test, seq_length=seq_length)
M_TEST = X_test.shape[0]

predict_probas = model.predict(x=X_test, batch_size=M_TEST, verbose=1)
# Out:
# 1/1 [==============================] - 1s 901ms/step

# %%
fpr, tpr, thresholds = roc_curve(y_test, predict_probas.ravel())

plt.figure()
plt.plot(fpr, tpr, label='LSTM (area = %0.2f)' % _roc_auc_score)

plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('LSTM ROC Curve')
plt.legend(loc="lower right")

plt.savefig("/Users/guilhermepalazzo/Desktop/fig_lstm_roc_curve.png")

# %% [markdown]
# ### LogReg

# %%
model = catalog.load("logistic_regr_fitted_model")
X_test = catalog.load("logistic_regr_features_test")
y_test = catalog.load("logistic_regr_target_test")
y_pred = catalog.load("logistic_regr_model_predict")
# Out:
# 2023-03-12 22:30:22,420 - kedro.io.data_catalog - INFO - Loading data from `logistic_regr_fitted_model` (PickleDataSet)...
# 2023-03-12 22:30:22,443 - kedro.io.data_catalog - INFO - Loading data from `logistic_regr_features_test` (ParquetDataSet)...
# 2023-03-12 22:30:22,474 - kedro.io.data_catalog - INFO - Loading data from `logistic_regr_target_test` (ParquetDataSet)...
# 2023-03-12 22:30:22,482 - kedro.io.data_catalog - INFO - Loading data from `logistic_regr_model_predict` (ParquetDataSet)...

# %%
_roc_auc_score = roc_auc_score(y_true=y_test, y_score=y_pred)
_roc_auc_score
# Out:
# 0.5294661733615221

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.59      0.56       352
#            1       0.53      0.47      0.50       344
#
#     accuracy                           0.53       696
#    macro avg       0.53      0.53      0.53       696
# weighted avg       0.53      0.53      0.53       696

# %%
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])

plt.figure()
plt.plot(fpr, tpr, label='LogReg (area = %0.2f)' % _roc_auc_score)

plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('LogReg ROC Curve')
plt.legend(loc="lower right")

plt.savefig("/Users/guilhermepalazzo/Desktop/fig_logreg_roc_curve.png")
